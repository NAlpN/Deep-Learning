# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import librosa
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

# %%
voice_path = '17973-2-0-32.wav'

librosa_audio_data, librosa_sample_data = librosa.load(voice_path)

# %%
print(librosa_audio_data)
# Out:
# [ 0.0591024   0.04647241 -0.02115159 ... -0.0069612   0.03259261
#   0.09148587]

# %%
plt.figure(figsize = (12, 4))
plt.plot(librosa_audio_data)
plt.show()

# %%
from scipy.io import wavfile as wav

wave_sample_rate, wave_audio = wav.read(voice_path)

# %%
wave_audio
# Out:
# array([[2189, 3314],
#        [1592, 2598],
#        [ 848, 1712],
#        ...,
#        [1326, 2602],
#        [1915, 3542],
#        [2542, 4449]], dtype=int16)

# %%
plt.figure(figsize = (12, 4))
plt.plot(wave_audio)
plt.show()

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_data, n_mfcc=40)

print(mfccs)
# Out:
# [[-166.06232   -151.50264   -172.7387    ... -192.53252   -179.10657
#   -179.59177  ]
#  [  75.67847     93.39499    109.31447   ...  107.66586     87.264244
#     67.258606 ]
#  [-107.505295  -118.782585  -128.7536    ... -112.772415   -97.96594
#    -85.718735 ]
#  ...
#  [  -9.795129    -8.940212   -14.132217  ...   -6.595042    -2.1138756
#     -5.7154036]
#  [   5.047469     3.6141496    5.1923423 ...   -4.643526   -11.839522
#    -17.177223 ]
#  [   4.929693     7.5509953    7.0431566 ...   -2.6938505   -6.5428867
#     -7.3473134]]
